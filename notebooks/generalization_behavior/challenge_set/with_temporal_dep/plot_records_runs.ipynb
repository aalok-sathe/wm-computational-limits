# %%
from pathlib import Path
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

# %%
basepath = Path(".")

dfs = []
for p in basepath.glob("*.csv"):
    if any(["tdprob=1_" in str(p), "tdprob=0_" in str(p)]):
        dfs += [pd.read_csv(p)]

# %%
df = pd.concat(dfs, ignore_index=True)
df

# %%
g = sns.FacetGrid(
    df,
    row="td_prob",
    col="role_n_congruence",
    # col_wrap=6,
    sharey=False,
    height=6,
    ylim=(0.9, 1),
)
y = "test_acc"
g.map_dataframe(sns.lineplot, x="epoch", y=y, hue="run_id", palette="Reds")
g.set_axis_labels("epoch", y)
# g.set_titles(col_template="role_n_cong = {col_name}")

for a in g.axes.flat:
    a.grid(True)  # enable grid on each facet

plt.tight_layout()
